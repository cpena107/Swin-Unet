# %%
from dataset_synapse import *

# %%
from glob import glob
import os
import random
import h5py
import numpy as np
import torch
from scipy import ndimage
from scipy.ndimage import zoom
from torch.utils.data import Dataset
import nibabel as nib
import random
import torchvision.transforms as transforms

# %%
def normalize_image(image):
    #norm_image = np.empty((image.shape[0], image.shape[1], image.shape[2]), np.float32)
    #for matrix in image:
    norm_image = (image-np.min(image)) / (np.max(image)-np.min(image))
    return norm_image

# %%
def zoom_image(image, label):
    original_height, original_width = image.shape[:2]
    new_height = int(original_height * 1.2)
    new_width = int(original_width * 1.2)

    zoom_image = zoom(image, (1.2, 1.2, 1), order=3)
    zoom_label = zoom(label, (1.2, 1.2, 1), order=0)

    start_x = (zoom_image.shape[1] - original_width) // 2
    start_y = (zoom_image.shape[0] - original_height) // 2

    cropped_image = zoom_image[start_y:start_y + original_height, start_x:start_x + original_width]
    cropped_label = zoom_label[start_y:start_y + original_height, start_x:start_x + original_width]

    return cropped_image, cropped_label

# %%
def transformations(image_file, label_file):
    # Shape: (*, 512, 512)
    m, s = np.mean(image_file, axis=(0, 1)), np.std(image_file, axis=(0, 1))
    try:
        preprocess_image = transforms.Compose([
            transforms.ToTensor(),
            transforms.Resize((512, 512)),
            transforms.Normalize(mean=m, std=s),
        ])
        #print(image_file.shape)
        img_data = preprocess_image(image_file).squeeze(0)
    except:
        preprocess_image = transforms.Compose([
            transforms.ToTensor(),
            transforms.Resize((512, 512)),
        ])
        #print(image_file.shape)
        img_data = preprocess_image(image_file).squeeze(0)
    #print(img_data.shape)
    preprocess_label = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize((512, 512)),
    ])
    #print(label_file.shape)
    lbl_data = preprocess_label(label_file).squeeze(0)
    #print(lbl_data.shape)
    return img_data, lbl_data

# %%
def nii_to_hdf5(image_file, label_file, output_h5):
    with h5py.File(output_h5+".npy.h5", 'w') as h5f:
        #img_data = np.transpose(img_data, (2, 0, 1))
        #lbl_data = np.transpose(lbl_data, (2, 0, 1))
        
        # Create datasets in the HDF5 file
        h5f.create_dataset('image', data=image_file, dtype='float32')
        h5f.create_dataset('label', data=label_file, dtype='uint8')

        print(f"Saved datasets to {output_h5} successfully.")

# %%
def get_trainning_data(nii_file1, nii_file2, output_npz): 
    for slice_num in range(1, nii_file1.shape[0]):
        image_slice = nii_file1.numpy()[slice_num, :, :]
        label_slice = nii_file2.numpy()[slice_num, :, :]
        
        # Save the numpy arrays as a .npz file
        np.savez(output_npz+"_slice"+str(slice_num), image=image_slice, label=label_slice)
    print(f"Saved {output_npz} slices successfully.")

# %%
def filenames_with_relative_paths(folder_path, train_folder, test_folder):
    # Loop through all directories and files in the given folder
    datasets = ["Training-Testing", "Training-Training"]
    for dataset in datasets:
        for root, dirs, files in os.walk(os.path.join(folder_path, dataset, "img")):
            if not root.split('/')[-1].startswith("00"):
                continue
            test = True
            random.shuffle(files)
            for file in files:
                print(f"Current {file}")
                image_path = os.path.join(root, file)
                label_path = image_path.replace('img', 'label')
                file_name = "case"+root.split('/')[-1]+'_'+file[4:6]
                # Load the .nii.gz files
                image = nib.load(image_path)
                label = nib.load(label_path)
                image = image.get_fdata()
                image = np.clip(image, -125, 275)
                image = normalize_image(image)
                label = label.get_fdata()

                # crop
                crop_size = 380
                start_row = (image.shape[0] - crop_size)//2
                start_col = (image.shape[0] - crop_size)//2
                image = image[start_row:start_row+crop_size, start_col:start_col+crop_size, :]
                label = label[start_row:start_row+crop_size, start_col:start_col+crop_size, :]
                
                # Transformations
                image, label = transformations(image, label)
                
                if test and dataset == "Training-Testing":
                    nii_to_hdf5(image, label, os.path.join(test_folder, file_name))
                    test = False
                else:
                    get_trainning_data(image, label, os.path.join(train_folder, file_name))
                
    # Original name: /label or img/0079/img0034-0079.nii.gz
    # Target name: case0079_slice034.npz

# %%
# !rm -rf Synapse/train_npz/*
# !rm -rf Synapse/test_vol_h5/*

# create train_npz
train_folder = "Synapse/train_npz"
os.makedirs(train_folder, exist_ok=True)

# create test_vol_h5
test_folder = "Synapse/test_vol_h5"
os.makedirs(test_folder, exist_ok=True)

# Replace with your folder path
folder_path = "Synapse/data_multi_organ/Abdomen/Abdomen/RegData"
filenames_with_relative_paths(folder_path, train_folder, test_folder)
# Out:
# Current img0010-0079.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0079_01 successfully.
# Current img0040-0079.nii.gz
# Saved Synapse/train_npz/case0079_04 slices successfully.
# Current img0009-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0035-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0039-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0031-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0038-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0024-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0004-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0026-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0030-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0037-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0033-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0028-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0003-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0008-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0007-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0029-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0002-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0025-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0032-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0022-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0005-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0027-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0006-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0001-0079.nii.gz
# Saved Synapse/train_npz/case0079_00 slices successfully.
# Current img0036-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0023-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0034-0079.nii.gz
# Saved Synapse/train_npz/case0079_03 slices successfully.
# Current img0021-0079.nii.gz
# Saved Synapse/train_npz/case0079_02 slices successfully.
# Current img0008-0065.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0065_00 successfully.
# Current img0006-0065.nii.gz
# Saved Synapse/train_npz/case0065_00 slices successfully.
# Current img0024-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0031-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0026-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0038-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0002-0065.nii.gz
# Saved Synapse/train_npz/case0065_00 slices successfully.
# Current img0005-0065.nii.gz
# Saved Synapse/train_npz/case0065_00 slices successfully.
# Current img0040-0065.nii.gz
# Saved Synapse/train_npz/case0065_04 slices successfully.
# Current img0036-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0001-0065.nii.gz
# Saved Synapse/train_npz/case0065_00 slices successfully.
# Current img0003-0065.nii.gz
# Saved Synapse/train_npz/case0065_00 slices successfully.
# Current img0039-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0009-0065.nii.gz
# Saved Synapse/train_npz/case0065_00 slices successfully.
# Current img0007-0065.nii.gz
# Saved Synapse/train_npz/case0065_00 slices successfully.
# Current img0035-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0030-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0025-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0023-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0010-0065.nii.gz
# Saved Synapse/train_npz/case0065_01 slices successfully.
# Current img0021-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0032-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0027-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0028-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0022-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0033-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0004-0065.nii.gz
# Saved Synapse/train_npz/case0065_00 slices successfully.
# Current img0037-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0029-0065.nii.gz
# Saved Synapse/train_npz/case0065_02 slices successfully.
# Current img0034-0065.nii.gz
# Saved Synapse/train_npz/case0065_03 slices successfully.
# Current img0036-0063.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0063_03 successfully.
# Current img0039-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0022-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0040-0063.nii.gz
# Saved Synapse/train_npz/case0063_04 slices successfully.
# Current img0032-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0034-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0009-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0038-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0024-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0030-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0007-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0001-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0008-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0033-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0037-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0029-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0010-0063.nii.gz
# Saved Synapse/train_npz/case0063_01 slices successfully.
# Current img0031-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0021-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0005-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0002-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0027-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0023-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0026-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0035-0063.nii.gz
# Saved Synapse/train_npz/case0063_03 slices successfully.
# Current img0003-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0004-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0025-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0006-0063.nii.gz
# Saved Synapse/train_npz/case0063_00 slices successfully.
# Current img0028-0063.nii.gz
# Saved Synapse/train_npz/case0063_02 slices successfully.
# Current img0025-0080.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0080_02 successfully.
# Current img0038-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0033-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0001-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0010-0080.nii.gz
# Saved Synapse/train_npz/case0080_01 slices successfully.
# Current img0009-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0040-0080.nii.gz
# Saved Synapse/train_npz/case0080_04 slices successfully.
# Current img0035-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0006-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0039-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0036-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0034-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0021-0080.nii.gz
# Saved Synapse/train_npz/case0080_02 slices successfully.
# Current img0026-0080.nii.gz
# Saved Synapse/train_npz/case0080_02 slices successfully.
# Current img0007-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0004-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0028-0080.nii.gz
# Saved Synapse/train_npz/case0080_02 slices successfully.
# Current img0005-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0024-0080.nii.gz
# Saved Synapse/train_npz/case0080_02 slices successfully.
# Current img0022-0080.nii.gz
# Saved Synapse/train_npz/case0080_02 slices successfully.
# Current img0027-0080.nii.gz
# Saved Synapse/train_npz/case0080_02 slices successfully.
# Current img0008-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0002-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0029-0080.nii.gz
# Saved Synapse/train_npz/case0080_02 slices successfully.
# Current img0037-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0003-0080.nii.gz
# Saved Synapse/train_npz/case0080_00 slices successfully.
# Current img0023-0080.nii.gz
# Saved Synapse/train_npz/case0080_02 slices successfully.
# Current img0031-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0030-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0032-0080.nii.gz
# Saved Synapse/train_npz/case0080_03 slices successfully.
# Current img0010-0075.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0075_01 successfully.
# Current img0031-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0026-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0025-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0002-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0003-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0034-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0030-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0036-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0040-0075.nii.gz
# Saved Synapse/train_npz/case0075_04 slices successfully.
# Current img0022-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0004-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0035-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0029-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0008-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0023-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0024-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0028-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0032-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0039-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0027-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0005-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0001-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0009-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0006-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0007-0075.nii.gz
# Saved Synapse/train_npz/case0075_00 slices successfully.
# Current img0033-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0037-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0038-0075.nii.gz
# Saved Synapse/train_npz/case0075_03 slices successfully.
# Current img0021-0075.nii.gz
# Saved Synapse/train_npz/case0075_02 slices successfully.
# Current img0026-0072.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0072_02 successfully.
# Current img0028-0072.nii.gz
# Saved Synapse/train_npz/case0072_02 slices successfully.
# Current img0001-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0027-0072.nii.gz
# Saved Synapse/train_npz/case0072_02 slices successfully.
# Current img0030-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0035-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0008-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0034-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0032-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0036-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0038-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0007-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0039-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0004-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0022-0072.nii.gz
# Saved Synapse/train_npz/case0072_02 slices successfully.
# Current img0033-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0029-0072.nii.gz
# Saved Synapse/train_npz/case0072_02 slices successfully.
# Current img0025-0072.nii.gz
# Saved Synapse/train_npz/case0072_02 slices successfully.
# Current img0037-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0010-0072.nii.gz
# Saved Synapse/train_npz/case0072_01 slices successfully.
# Current img0040-0072.nii.gz
# Saved Synapse/train_npz/case0072_04 slices successfully.
# Current img0003-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0023-0072.nii.gz
# Saved Synapse/train_npz/case0072_02 slices successfully.
# Current img0002-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0024-0072.nii.gz
# Saved Synapse/train_npz/case0072_02 slices successfully.
# Current img0021-0072.nii.gz
# Saved Synapse/train_npz/case0072_02 slices successfully.
# Current img0031-0072.nii.gz
# Saved Synapse/train_npz/case0072_03 slices successfully.
# Current img0006-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0009-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0005-0072.nii.gz
# Saved Synapse/train_npz/case0072_00 slices successfully.
# Current img0040-0078.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0078_04 successfully.
# Current img0035-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0010-0078.nii.gz
# Saved Synapse/train_npz/case0078_01 slices successfully.
# Current img0005-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0032-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0025-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0029-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0003-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0038-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0021-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0009-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0037-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0031-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0026-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0027-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0023-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0002-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0033-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0030-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0036-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0008-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0001-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0039-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0007-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0004-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0034-0078.nii.gz
# Saved Synapse/train_npz/case0078_03 slices successfully.
# Current img0006-0078.nii.gz
# Saved Synapse/train_npz/case0078_00 slices successfully.
# Current img0028-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0024-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0022-0078.nii.gz
# Saved Synapse/train_npz/case0078_02 slices successfully.
# Current img0030-0071.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0071_03 successfully.
# Current img0032-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0028-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0024-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0007-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0036-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0027-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0029-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0005-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0004-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0003-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0021-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0031-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0037-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0035-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0023-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0010-0071.nii.gz
# Saved Synapse/train_npz/case0071_01 slices successfully.
# Current img0040-0071.nii.gz
# Saved Synapse/train_npz/case0071_04 slices successfully.
# Current img0022-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0034-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0009-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0006-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0008-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0039-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0002-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0038-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0001-0071.nii.gz
# Saved Synapse/train_npz/case0071_00 slices successfully.
# Current img0025-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0033-0071.nii.gz
# Saved Synapse/train_npz/case0071_03 slices successfully.
# Current img0026-0071.nii.gz
# Saved Synapse/train_npz/case0071_02 slices successfully.
# Current img0034-0066.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0066_03 successfully.
# Current img0026-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0036-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0006-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0025-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0022-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0040-0066.nii.gz
# Saved Synapse/train_npz/case0066_04 slices successfully.
# Current img0003-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0023-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0010-0066.nii.gz
# Saved Synapse/train_npz/case0066_01 slices successfully.
# Current img0002-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0009-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0008-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0005-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0031-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0028-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0029-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0030-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0004-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0033-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0027-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0039-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0007-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0038-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0001-0066.nii.gz
# Saved Synapse/train_npz/case0066_00 slices successfully.
# Current img0032-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0024-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0021-0066.nii.gz
# Saved Synapse/train_npz/case0066_02 slices successfully.
# Current img0037-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0035-0066.nii.gz
# Saved Synapse/train_npz/case0066_03 slices successfully.
# Current img0030-0077.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0077_03 successfully.
# Current img0036-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0008-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0006-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0032-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0024-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0002-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0035-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0005-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0023-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0037-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0022-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0039-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0010-0077.nii.gz
# Saved Synapse/train_npz/case0077_01 slices successfully.
# Current img0034-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0004-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0028-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0003-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0029-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0026-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0040-0077.nii.gz
# Saved Synapse/train_npz/case0077_04 slices successfully.
# Current img0001-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0031-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0021-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0027-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0033-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0025-0077.nii.gz
# Saved Synapse/train_npz/case0077_02 slices successfully.
# Current img0009-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0038-0077.nii.gz
# Saved Synapse/train_npz/case0077_03 slices successfully.
# Current img0007-0077.nii.gz
# Saved Synapse/train_npz/case0077_00 slices successfully.
# Current img0026-0061.nii.gz
# Saved datasets to Synapse/test_vol_h5/case0061_02 successfully.
# Current img0022-0061.nii.gz
# Saved Synapse/train_npz/case0061_02 slices successfully.
# Current img0024-0061.nii.gz
# Saved Synapse/train_npz/case0061_02 slices successfully.
# Current img0002-0061.nii.gz
# Saved Synapse/train_npz/case0061_00 slices successfully.
# Current img0005-0061.nii.gz
# Saved Synapse/train_npz/case0061_00 slices successfully.
# Current img0040-0061.nii.gz
# Saved Synapse/train_npz/case0061_04 slices successfully.
# Current img0010-0061.nii.gz
# Saved Synapse/train_npz/case0061_01 slices successfully.
# Current img0023-0061.nii.gz
# Saved Synapse/train_npz/case0061_02 slices successfully.
# Current img0034-0061.nii.gz
# Saved Synapse/train_npz/case0061_03 slices successfully.
# Current img0039-0061.nii.gz
# Saved Synapse/train_npz/case0061_03 slices successfully.
# Current img0009-0061.nii.gz
# Saved Synapse/train_npz/case0061_00 slices successfully.
# Current img0021-0061.nii.gz
# Saved Synapse/train_npz/case0061_02 slices successfully.
# Current img0001-0061.nii.gz
# Saved Synapse/train_npz/case0061_00 slices successfully.
# Current img0007-0061.nii.gz
# Saved Synapse/train_npz/case0061_00 slices successfully.
# Current img0032-0061.nii.gz
# Saved Synapse/train_npz/case0061_03 slices successfully.
# Current img0038-0061.nii.gz
# Saved Synapse/train_npz/case0061_03 slices successfully.
# Current img0027-0061.nii.gz
# Saved Synapse/train_npz/case0061_02 slices successfully.
# Current img0037-0061.nii.gz
# Saved Synapse/train_npz/case0061_03 slices successfully.
# Current img0025-0061.nii.gz
# Saved Synapse/train_npz/case0061_02 slices successfully.
# Current img0028-0061.nii.gz
# Saved Synapse/train_npz/case0061_02 slices successfully.
# Current img0008-0061.nii.gz
# Saved Synapse/train_npz/case0061_00 slices successfully.
# Current img0030-0061.nii.gz
# Saved Synapse/train_npz/case0061_03 slices successfully.
# Current Untitled.ipynb
# ---------------------------------------------------------------------------
# ImageFileError                            Traceback (most recent call last)
# Cell In[9], line 14
#      12 # Replace with your folder path
#      13 folder_path = "Synapse/data_multi_organ/Abdomen/Abdomen/RegData"
# ---> 14 filenames_with_relative_paths(folder_path, train_folder, test_folder)
#
# Cell In[8], line 16, in filenames_with_relative_paths(folder_path, train_folder, test_folder)
#      14 file_name = "case"+root.split('/')[-1]+'_'+file[4:6]
#      15 # Load the .nii.gz files
# ---> 16 image = nib.load(image_path)
#      17 label = nib.load(label_path)
#      18 image = image.get_fdata()
#
# File ~/miniconda3/envs/SwinUnetTests/lib/python3.12/site-packages/nibabel/loadsave.py:117, in load(filename, **kwargs)
#     114 if not matches:
#     115     raise ImageFileError(msg)
# --> 117 raise ImageFileError(f'Cannot work out file type of "{filename}"')
#
# ImageFileError: Cannot work out file type of "Synapse/data_multi_organ/Abdomen/Abdomen/RegData/Training-Testing/img/0061/Untitled.ipynb"

# %%
# !rm ../lists/lists_Synapse/train.txt
# !rm ../lists/lists_Synapse/test_vol.txt

# !.././get_train_data.sh Synapse/train_npz ../lists/lists_Synapse/train.txt train
# !.././get_train_data.sh Synapse/test_vol_h5 ../lists/lists_Synapse/test_vol.txt test
# Out:
# train
# File names without extensions have been written to: ../lists/lists_Synapse/train.txt
# test
# File names without extensions have been written to: ../lists/lists_Synapse/test_vol.txt

# %%
# !cd ../..
# !ls
# !./train.sh
# Out:
# dataset_synapse.ipynb  Preprocessing.ipynb  README.md
# dataset_synapse.py     __pycache__	    Synapse
# /bin/bash: line 1: ./train.sh: No such file or directory
